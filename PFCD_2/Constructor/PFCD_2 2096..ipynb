# %%
class Student:
    def __init__(self):
        self.name="Abhijeet"
        self.age=21
        self.mark=90

    def talk(self):
        print('Name is',self.name)
        print(self.age)
        print(self.mark)
    
S1=Student()
talk(S1)
# Out:
# Name is Abhijeet
# 21
# 90

# %%
class Student:
    def __init__(self, redg, sec):
        self.name = "Abhijeet"
        self.age = 21
        self.mark = 90
        self.redg = redg  
        self.sec = sec    

    def talk(self):
        print('Name is', self.name)
        print(self.age)
        print(self.mark)
        print( self.redg)
        print( self.sec)


S1 = Student(2069, '2c1')
S1.talk()
# Out:
# Name is Abhijeet
# 21
# 90
# 2069
# 2c1

# %%
class Sample:
    def __init__(self):
        self.x=10
    def modify(self):
        self.x+=1
        
S1=Sample()
S2=Sample()
print('X in S1=',S1.x)
print('X in S2=',S2.x)
S1.modify()
print('X in S1=',S1.x)
print('X in S2=',S2.x)
# Out:
# X in S1= 10
# X in S2= 10
# X in S1= 11
# X in S2= 10

# %%
class Sample:
    x=10
    
    @classmethod
    def modify(cls):
        cls.x+=1
        
S1=Sample()
S2=Sample()
print('X in S1=',S1.x)
print('X in S2=',S2.x)
S1.modify()
print('X in S1=',S1.x)
print('X in S2=',S2.x)
# Out:
# X in S1= 10
# X in S2= 10
# X in S1= 11
# X in S2= 11
